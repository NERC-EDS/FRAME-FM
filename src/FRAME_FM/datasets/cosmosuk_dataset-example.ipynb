# %%
import sys
sys.path.append("/home/users/colinsau/FRAME-FM/src/")
import FRAME_FM.datasets.cosmosuk_dataset as cosmosuk

# %%
#/gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/
#data = cosmosuk.CosmosUKDataset(data_uri="/home/users/colinsau/FRAME-FM/tests/datasets/fixtures/cosmos-uk/")
data = cosmosuk.CosmosUKDataset(data_uri="/gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/")
# Out:
# Loading file /gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/cosmos-uk_alic1_hydrosoil_sh_2015-2024.csv
# Loading file /gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/cosmos-uk_balrd_hydrosoil_sh_2014-2024.csv
# Loading file /gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/cosmos-uk_bickl_hydrosoil_sh_2015-2024.csv
# Loading file /gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/cosmos-uk_bunny_hydrosoil_sh_2015-2024.csv
# Loading file /gws/ssde/j25b/eds_ai/frame-fm/data/inputs/daily_and_subdaily_hydrometeorological_and_soil_moisture_data/data/cosmos-uk_cardt_hydrosoil_sh_2015-2024.csv
# ...

# %%
data.data
# Out:
# [<xarray.Dataset> Size: 144B
#  Dimensions:     (TIME_DATE: 9, DATE_TIME: 9)
#  Coordinates:
#    * DATE_TIME   (DATE_TIME) datetime64[ns] 72B 2014-05-15T17:30:00 ... 2014-0...
#  Dimensions without coordinates: TIME_DATE
#  Data variables:
#      TDT1_TSOIL  (TIME_DATE) float64 72B nan nan nan nan nan nan nan nan nan
#  Attributes:
#      latitude:   56.482297
#      longitude:  -3.1114881
#      site_id:    BALRD]

# %%
data.data[0]['TDT1_TSOIL']
# Out:
# np.float64(5.89)

# %%
#save result
#ds.to_netcdf("/gws/ssde/j25b/eds_ai/frame-fm/users/colinsau/cosmos-uk-hydrosoil.nc")
